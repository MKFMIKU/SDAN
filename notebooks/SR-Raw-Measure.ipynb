# %%
import sys 
sys.path.append("..")

import numpy as np
import cv2
import matplotlib.pyplot as plt

from tqdm import tqdm_notebook

from datasets.srraw_dataset import SRRawDataset

from datasets.zoom_utils import reshape_raw

# %%
class config:
    scale = [16]
    patch_size = 512

dataset = SRRawDataset(config,
                       train=True,
                       dataroot='/tmp_data/running/SRRaw/train/')

# %%
try:
    batch = next(iter(dataset))
except Exception as e:
    print(repr(e))

# %%
lr = batch['data']
hr = batch['label']

# %%
plt.imshow(lr.numpy().transpose(1,2,0))

# %%
plt.imshow(hr.numpy().transpose(1,2,0))

# %%
lr = batch['data']
lr_y = batch['data_rgb']
hr_y = batch['label']
pad_h = batch['pad_h']
pad_w = batch['pad_w']

# %%
hr_y = hr_y[:, pad_h * 16 // 4:-(pad_h + 1) * 16 // 4,
                 pad_w * 16 // 4:-(pad_w + 1) * 16 // 4]
lr_y = lr_y[:, pad_h:-(pad_h+1), pad_w:-(pad_w+1)]

# %%
plt.imshow(hr_y.numpy().transpose(1,2,0))

# %%
plt.imshow(lr_y.numpy().transpose(1,2,0))
